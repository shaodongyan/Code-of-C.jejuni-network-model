# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/media/dell/cdcc2551-b430-4b85-a0f1-c628cb818672/zhenjun/shamen/ag'

# %%
df = TabularDataset('./jiewan-suyuan/training.csv')

# %%
label_column = 'origin' # specifies which column do we want to predict
savedir = './jiewan-suyuan/test1/' # where to save trained models
predictor = TabularPredictor(
                        label=label_column,
                        path=savedir
                        ).fit(df,presets='best_quality',auto_stack="T")
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.14
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #146~16.04.1-Ubuntu SMP Tue Apr 13 09:27:15 UTC 2021
# CPU Count:          32
# Memory Avail:       83.41 GB / 93.06 GB (89.6%)
# Disk Space Avail:   5532.17 GB / 18460.53 GB (30.0%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=T): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-09-27 16:48:19,784	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8267
# 		Context path: "./jiewan-suyuan/test1/ds_sub_fit/sub_fit_ho"
# (_dystack pid=29375) Running DyStack sub-fit ...
# (_dystack pid=29375) Beginning AutoGluon training ... Time limit = 895s
# (_dystack pid=29375) AutoGluon will save models to "./jiewan-suyuan/test1/ds_sub_fit/sub_fit_ho"
# (_dystack pid=29375) Train Data Rows:    1124
# (_dystack pid=29375) Train Data Columns: 5502
# (_dystack pid=29375) Label Column:       origin
# (_dystack pid=29375) Problem Type:       multiclass
# (_dystack pid=29375) Preprocessing data ...
# (_dystack pid=29375) Train Data Class Count: 3
# (_dystack pid=29375) Using Feature Generators to preprocess the data ...
# (_dystack pid=29375) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=29375) 	Available Memory:                    84728.65 MB
# (_dystack pid=29375) 	Train Data (Original)  Memory Usage: 5.90 MB (0.0% of available memory)
# (_dystack pid=29375) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=29375) 	Stage 1 Generators:
# (_dystack pid=29375) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=29375) 			Note: Converting 5019 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=29375) 	Stage 2 Generators:
# (_dystack pid=29375) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=29375) 	Stage 3 Generators:
# (_dystack pid=29375) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=29375) 	Stage 4 Generators:
# (_dystack pid=29375) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=29375) 	Stage 5 Generators:
# (_dystack pid=29375) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=29375) 	Useless Original Features (Count: 483): ['group_2529', 'ackA', 'group_2448', 'tdcB', 'hom', 'rplB', 'group_2431', 'bamA', 'slt', 'actP', 'ilvD', 'guaA', 'group_2411', 'engB', 'fbp', 'ruvA', 'group_2406', 'group_2402', 'group_2399', 'rpiB', 'group_2395', 'bpt...bpt_1...bpt_2', 'group_2393', 'dnaE', 'slyD', 'group_2356', 'dusB', 'atpD', 'folP', 'group_2297', 'atoC...dctD', 'group_2283', 'group_2271', 'purD', 'group_2218', 'purH', 'ycaD', 'group_2152', 'rplN', 'msrAB...msrA', 'group_2128', 'lptB_2', 'rpsZ', 'group_2074', 'group_2071', 'pal', 'group_2065', 'peb1A', 'group_2040', 'rplE', 'rpsH', 'gltA', 'sucC', 'group_2018', 'fliP', 'soj', 'lepA', 'group_2005', 'hiuH', 'glnM', 'aroA', 'group_1995', 'group_1994', 'group_1990', 'rpsS', 'flgG_1', 'group_1976', 'group_1966', 'fapR', 'murB', 'ilvC', 'lutA_2', 'group_1929', 'group_1925', 'glnA', 'group_1918', 'group_1908', 'cfiB', 'group_1900', 'group_1898', 'proP_2...yhjE...proP_3...proP_1...ousA', 'mltD', 'group_1894', 'group_1890', 'clpY', 'group_1883', 'ispH', 'metG', 'aroH', 'ilvH', 'hslV', 'yocK', 'group_1854', 'group_1853', 'lepB', 'cbf2', 'group_1831', 'pepA', 'group_1821', 'group_1819', 'group_1818', 'argH', 'folD', 'group_1813', 'murG', 'glyQ', 'rppH', 'yccU', 'recN', 'ycfH', 'alaC', 'group_1797', 'purE', 'group_1789', 'pheT', 'group_1761', 'pckA', 'atpG_2...atpG_1...atpG', 'group_1756', 'group_1755', 'group_1751', 'group_1737', 'nadK', 'group_1731', 'atpE', 'group_1715', 'cysK', 'artQ', 'pdxA', 'atpA', 'hup', 'fmt', 'group_1670', 'lptD', 'prs', 'pheS', 'serA', 'group_1638', 'group_1630', 'group_1602', 'group_1596', 'rpsA', 'ccsA', 'rhaS...exsA', 'yycB...nimT', 'cmoA', 'group_1436', 'group_1435', 'group_1434', 'group_1433', 'miaA', 'queE', 'mntP', 'group_1423', 'sodB', 'group_1400', 'yicL...yicL_1', 'group_1381', 'group_1374', 'oadA', 'rsmI_1...rsmI_2...rsmI', 'group_1353', 'atpC', 'exbD_1', 'ribBA', 'group_1280', 'trpC_1...trpC_3...trpC_2', 'group_1262', 'ftsW', 'group_1237', 'ansZ', 'group_1211', 'trmL...trmL_1...trmL_2', 'pleD', 'group_1193', 'group_1183', 'group_1176', 'group_1168', 'ydfG', 'alr', 'queA', 'group_1159', 'oprF', 'group_1141', 'group_1137', 'uppS', 'recJ', 'group_1110', 'selU', 'apt...apt_1...apt_2', 'group_1104', 'group_1095', 'prpD', 'group_1076', 'group_1071', 'group_1065', 'mrdA', 'ypdF', 'rsmG', 'pfeA...cirA_2...fepA...cirA_1...cirA_3', 'group_1026', 'purN', 'alsT...alsT_2...alsT_1', 'comM', 'glnP_2', 'cstA', 'pnp', 'flhA_2...flhA_1...flhA', 'group_982', 'rpsO', 'pfs_1...pfs', 'group_922', 'argF', 'group_914', 'ybeY', 'group_907', 'rpoN...rpoN_1...rpoN_2', 'tsaE', 'group_894', 'group_886', 'tatC', 'group_876', 'group_875', 'group_870', 'truA', 'gyrA', 'group_864', 'group_855', 'rsmA', 'group_847', 'PROSC', 'dapB', 'group_821', 'fba', 'group_753', 'group_748', 'group_739', 'group_732', 'rplF', 'bioB', 'hemL...hemL1', 'group_718', 'glmU', 'accC', 'tig...tig_2', 'atpF', 'yisK', 'rbr1', 'rplP', 'fliQ', 'group_679', 'group_678', 'rnr', 'amt...nrgA...nrgA_2...nrgA_1', 'guaB', 'group_612', 'group_605', 'group_595', 'group_593', 'secY', 'rpsE', 'dsbI', 'ispG', 'rplR', 'group_545', 'gltB_2...gltB_1...gltB', 'rplI', 'livF', 'fhaB...fhaB_2...ibpA', 'fhaC...fhaC_2...fhaC_1', 'group_489', 'nnr...nnr_2...nnr_1', 'glnQ_2...glnQ_3', 'pdxJ', 'rplM', 'group_449', 'lolE', 'rpsP', 'purF...purF_1', 'group_372', 'group_368', 'group_360', 'yajL', 'rpsG', 'ribF', 'argG', 'rpmE', 'group_321', 'glnH', 'aas...lplT', 'group_296', 'futA1', 'group_295', 'group_292', 'cymR', 'fabD', 'ttcA', 'yajC', 'rpsI', 'pepD_1...pepD_2...pepD', 'rplW', 'rpsC', 'rimM', 'sbmA', 'nucH', 'group_111', 'hemB', 'ppa', 'adk', 'parB', 'uup_1...uup', 'lptB_2...lptB_1', 'hemN', 'group_48', 'flaC', 'livH', 'group_43', 'psd', 'ffh', 'group_40', 'flgG_1...flgG_2', 'rplD', 'rpsQ', 'acnB', 'group_25', 'lpxD', 'group_22', 'fusA', 'group_21', 'rlmH', 'group_11', 'mntB...znuB...mntC', 'rlmN', 'rnj', 'fokIM...fokIM_1', 'grpE', 'cheB', 'group_1914', 'rlmB', 'accD', 'trxB', 'group_1593', 'moaA', 'm ...
# (_dystack pid=29375) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=29375) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=29375) 		These features do not need to be present at inference time.
# (_dystack pid=29375) 	Unused Original Features (Count: 1456): ['thiG', 'nrdA...nrdE', 'nth', 'thyX', 'metY', 'group_1954', 'ogt', 'group_1717', 'acsA...acs_1', 'ilvB', 'group_1241', 'mdtC...mdtB...mdtC_2...mdtC_1', 'group_1150', 'macA...macA_2...macA_1', 'gltX', 'asd', 'hipO', 'thrB', 'cobB_1...cobB', 'meh', 'tcyP', 'pyrG', 'rnhB', 'macB...macB_2', 'thiH', 'ychF', 'tdeA', 'group_463', 'moeA_2', 'ppk2', 'yiiM', 'dcuB_1...dcuB_3...dcuB_2...dcuB', 'metAA1', 'rsmF', 'rsmE', 'group_78', 'tlyA', 'group_2360', 'group_2130', 'ispB', 'ruvC', 'group_1542', 'cheR', 'lpxC', 'group_1212', 'dnaJ', 'uvrB...uvrB_1', 'ileS', 'group_859', 'nadD', 'group_726', 'algC', 'group_708', 'group_705', 'group_693', 'gyrB', 'dnaA', 'rsfS', 'secD', 'tenI', 'group_322', 'group_313', 'group_303', 'gltB_1...gltB_2...gltA_2', 'topA...topA_1', 'resE', 'leuS', 'group_187', 'bzaF', 'rpe', 'tpiA', 'hxuB...hxuB_1', 'group_2083', 'group_2001', 'group_1006', 'group_983', 'hemC', 'mepA', 'hldE...hldE_1', 'group_508', 'secF', 'acsA_2...acs...acs_1', 'group_413', 'proA', 'ssb', 'group_1615', 'hemA', 'lon_2...lon...lon_1', 'rpsR', 'group_10', 'mnmE', 'purL', 'rpsM', 'rpsD', 'group_1296', 'petB', 'petA', 'mnmG', 'group_635', 'group_603', 'group_396', 'infA', 'group_467', 'rnpA', 'group_344', 'rplQ', 'murD', 'gpmI', 'fabG_1...fabG', 'argS', 'pglB', 'group_949', 'pglI...pglI_2...pglI_1', 'group_647', 'mdtI', 'rpsB', 'group_328', 'mdtJ...nepB', 'yfkJ', 'group_1641', 'cheA_1...cheA...frzE_1', 'group_417', 'tsf', 'cyf', 'copA_2...ctpA_1...copA_1', 'rho', 'group_1134', 'pglC', 'pglA', 'lolD', 'copA_2', 'group_364', 'group_88', 'group_84', 'group_82', 'flgC', 'group_566', 'group_168', 'group_2077', 'argB', 'ypeA', 'group_1004', 'argC', 'ldh...ldh_2...ldh_1', 'fabF', 'purS', 'purQ', 'purC', 'group_2089', 'nuoL', 'nuoN', 'pcm', 'dcuD_1...dcuD_2...dcuD...dcuD_3', 'metC...metC_2...metC_1', 'group_891', 'group_773', 'group_198', 'clpB', 'nuoH', 'nuoK', 'nuoJ', 'group_624', 'group_1757', 'sstT...sstT_1...sstT_2', 'mcpQ...mcp4...mcp4_1', 'group_395', 'wbpE_2...desV...wbpE_1...wbpE', 'group_189', 'hxcR...epsE', 'group_188', 'yohD', 'group_2038', 'group_2037', 'frr', 'pyrE', 'group_834', 'group_731', 'pcrA', 'group_382', 'group_381', 'group_63', 'atpB', 'pyrH', 'group_2079', 'tyrS', 'group_2076', 'group_422', 'pyrC_1...pyrC_2...pyrC', 'metN_1...ftsE', 'group_158', 'spoT...relA', 'mnmC_2...mnmC_1...mnmC', 'tsaD', 'recR', 'czcS', 'hydB', 'group_156', 'group_414', 'group_162', 'rplJ', 'rplA', 'rplK', 'nusG', 'rpmG2', 'tufA', 'tpx', 'cysE', 'napA', 'napB', 'speA', 'yecS', 'ctb', 'group_547', 'group_320', 'metN', 'ispE', 'group_221', 'group_175', 'group_340', 'aat', 'group_1248', 'group_190', 'group_750', 'group_2032', 'sucD', 'korA', 'group_457', 'group_1079', 'group_462', 'group_458', 'group_421', 'group_2112', 'group_177', 'prfA', 'dapD', 'group_734', 'hisG', 'hisF_1', 'pgpA', 'mqo', 'group_263', 'serS', 'group_1997', 'yedF', 'group_940', 'der', 'group_178', 'mlaA', 'mqnE', 'group_749', 'nadE', 'group_418', 'group_179', 'msbA', 'group_1044', 'group_893', 'group_889', 'potA...cysA...malK...phnT', 'group_308', 'dapA', 'group_49', 'fabL', 'thrC', 'ylxH', 'folK', 'group_823', 'group_783', 'group_782', 'group_568', 'fliM', 'fliA', 'hpr', 'rplT', 'trpF...trpC_2...trpC_1', 'trpA', 'group_2322', 'group_2086', 'fliN', 'gppA', 'tcrA...cusR', 'pabB...trpE', 'cbpA', 'group_2104', 'group_100', 'group_109', 'prmA', 'ftsH', 'group_55', 'moaC1...moaC', 'group_616', 'group_201', 'lpxA', 'mreB...mreB_1', 'group_304', 'clpX', 'dgkA', 'group_530', 'lutB', 'group_723', 'group_754', 'ttuB...rhmT...rhmT_1...rhmT_2', 'group_369', 'uxaA_2...uxaA_1', 'glmM', 'yclQ...yclQ_2...yclQ_1', 'rpoD', 'ftsH3', 'mtaB', 'group_2239', 'glyA', 'group_1594', 'group_1517', 'group_254', 'aroE', 'lgt', 'frdA', 'frdC', 'group_744', 'group_2015', 'group_721', 'group_719', 'motB', 'group_2205', 'group_2204', 'group_2048', 'macB_2', 'group_232', 'tpd', 'group_2137', 'group_775', 'murI', 'map', 'nhaA_1...nhaA_2', 'group_2066', 'plsX', 'g ...
# (_dystack pid=29375) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=29375) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=29375) 		These features do not need to be present at inference time.
# (_dystack pid=29375) 		('bool', []) : 1456 | ['thiG', 'nrdA...nrdE', 'nth', 'thyX', 'metY', ...]
# (_dystack pid=29375) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=29375) 		('bool', []) : 3563 | ['gltX1', 'group_2424', 'yclP...yclP_2...yclP_1', 'rplX', 'group_2098', ...]
# (_dystack pid=29375) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=29375) 		('int', ['bool']) : 3563 | ['gltX1', 'group_2424', 'yclP...yclP_2...yclP_1', 'rplX', 'group_2098', ...]
# (_dystack pid=29375) 	68.7s = Fit runtime
# (_dystack pid=29375) 	3563 features in original data used to generate 3563 features in processed data.
# (_dystack pid=29375) 	Train Data (Processed) Memory Usage: 3.82 MB (0.0% of available memory)
# (_dystack pid=29375) Data preprocessing and feature engineering runtime = 69.39s ...
# (_dystack pid=29375) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=29375) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=29375) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=29375) User-specified model hyperparameters to be fit:
# (_dystack pid=29375) {
# (_dystack pid=29375) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=29375) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=29375) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=29375) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=29375) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=29375) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=29375) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=29375) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=29375) }
# (_dystack pid=29375) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=29375) Fitting 110 L1 models ...
# (_dystack pid=29375) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 550.32s of the 825.58s of remaining time.
# (_dystack pid=29375) 	No valid features to train KNeighborsUnif_BAG_L1... Skipping this model.
# (_dystack pid=29375) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 549.75s of the 825.01s of remaining time.
# (_dystack pid=29375) 	No valid features to train KNeighborsDist_BAG_L1... Skipping this model.
# (_dystack pid=29375) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 549.15s of the 824.41s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.05%)
# (_dystack pid=29375) 	0.9021	 = Validation score   (accuracy)
# (_dystack pid=29375) 	10.65s	 = Training   runtime
# (_dystack pid=29375) 	0.25s	 = Validation runtime
# (_dystack pid=29375) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 532.25s of the 807.46s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.79%)
# (_dystack pid=29375) 	0.9048	 = Validation score   (accuracy)
# (_dystack pid=29375) 	9.43s	 = Training   runtime
# (_dystack pid=29375) 	0.15s	 = Validation runtime
# (_dystack pid=29375) Fitting model: LightGBM_BAG_L1 ... Training model for up to 518.34s of the 793.59s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.79%)
# (_dystack pid=29375) 	0.9048	 = Validation score   (accuracy)
# (_dystack pid=29375) 	9.1s	 = Training   runtime
# (_dystack pid=29375) 	0.14s	 = Validation runtime
# (_dystack pid=29375) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 504.84s of the 780.09s of remaining time.
# (_dystack pid=29375) 	0.8968	 = Validation score   (accuracy)
# (_dystack pid=29375) 	3.16s	 = Training   runtime
# (_dystack pid=29375) 	1.45s	 = Validation runtime
# (_dystack pid=29375) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 498.63s of the 773.86s of remaining time.
# (_dystack pid=29375) 	0.8977	 = Validation score   (accuracy)
# (_dystack pid=29375) 	3.27s	 = Training   runtime
# (_dystack pid=29375) 	1.49s	 = Validation runtime
# (_dystack pid=29375) Fitting model: CatBoost_BAG_L1 ... Training model for up to 492.32s of the 767.57s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.60%)
# (_ray_fit pid=1750) 	Many features detected (3540), dynamically setting 'colsample_bylevel' to 0.2824858757062147 to speed up training (Default = 1).
# (_ray_fit pid=1750) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters.
# (_dystack pid=29375) 	0.8941	 = Validation score   (accuracy)
# (_dystack pid=29375) 	113.18s	 = Training   runtime
# (_dystack pid=29375) 	3.8s	 = Validation runtime
# (_ray_fit pid=1745) 	Many features detected (3537), dynamically setting 'colsample_bylevel' to 0.2827254735651682 to speed up training (Default = 1). [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=1745) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters. [repeated 7x across cluster]
# (_dystack pid=29375) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 374.26s of the 649.51s of remaining time.
# (_dystack pid=29375) 	0.8977	 = Validation score   (accuracy)
# (_dystack pid=29375) 	3.05s	 = Training   runtime
# (_dystack pid=29375) 	1.78s	 = Validation runtime
# (_dystack pid=29375) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 367.88s of the 643.13s of remaining time.
# (_dystack pid=29375) 	0.8986	 = Validation score   (accuracy)
# (_dystack pid=29375) 	3.21s	 = Training   runtime
# (_dystack pid=29375) 	1.54s	 = Validation runtime
# (_dystack pid=29375) Fitting model: XGBoost_BAG_L1 ... Training model for up to 361.5s of the 636.76s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.62%)
# (_dystack pid=29375) 	0.8986	 = Validation score   (accuracy)
# (_dystack pid=29375) 	11.26s	 = Training   runtime
# (_dystack pid=29375) 	0.16s	 = Validation runtime
# (_dystack pid=29375) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 345.9s of the 621.15s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# (_dystack pid=29375) 	0.9057	 = Validation score   (accuracy)
# (_dystack pid=29375) 	20.54s	 = Training   runtime
# (_dystack pid=29375) 	0.25s	 = Validation runtime
# (_dystack pid=29375) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 320.68s of the 595.93s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=3.18%)
# (_dystack pid=29375) 	0.8986	 = Validation score   (accuracy)
# (_dystack pid=29375) 	24.67s	 = Training   runtime
# (_dystack pid=29375) 	0.17s	 = Validation runtime
# (_dystack pid=29375) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 291.42s of the 566.67s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.60%)
# (_ray_fit pid=5116) 	Many features detected (3539), dynamically setting 'colsample_bylevel' to 0.2825656965244419 to speed up training (Default = 1).
# (_ray_fit pid=5116) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters.
# (_dystack pid=29375) 	0.903	 = Validation score   (accuracy)
# (_dystack pid=29375) 	173.15s	 = Training   runtime
# (_dystack pid=29375) 	4.04s	 = Validation runtime
# (_ray_fit pid=5118) 	Many features detected (3539), dynamically setting 'colsample_bylevel' to 0.2825656965244419 to speed up training (Default = 1). [repeated 7x across cluster]
# (_ray_fit pid=5118) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters. [repeated 7x across cluster]
# (_dystack pid=29375) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 113.63s of the 388.89s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# (_dystack pid=29375) 	0.8977	 = Validation score   (accuracy)
# (_dystack pid=29375) 	17.71s	 = Training   runtime
# (_dystack pid=29375) 	0.34s	 = Validation runtime
# (_dystack pid=29375) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 91.27s of the 366.53s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.34%)
# (_dystack pid=29375) 	0.9004	 = Validation score   (accuracy)
# (_dystack pid=29375) 	16.09s	 = Training   runtime
# (_dystack pid=29375) 	0.16s	 = Validation runtime
# (_dystack pid=29375) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 70.77s of the 346.02s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.05%)
# (_dystack pid=29375) 	0.9012	 = Validation score   (accuracy)
# (_dystack pid=29375) 	17.74s	 = Training   runtime
# (_dystack pid=29375) 	0.43s	 = Validation runtime
# (_dystack pid=29375) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 48.32s of the 323.57s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=6.31%)
# (_ray_fit pid=8512) 	Many features detected (3539), dynamically setting 'colsample_bylevel' to 0.2825656965244419 to speed up training (Default = 1).
# (_ray_fit pid=8512) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters.
# (_dystack pid=29375) 	0.8941	 = Validation score   (accuracy)
# (_dystack pid=29375) 	39.41s	 = Training   runtime
# (_dystack pid=29375) 	4.34s	 = Validation runtime
# (_ray_fit pid=8515) 	Many features detected (3540), dynamically setting 'colsample_bylevel' to 0.2824858757062147 to speed up training (Default = 1). [repeated 7x across cluster]
# (_ray_fit pid=8515) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters. [repeated 7x across cluster]
# (_dystack pid=29375) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 3.99s of the 279.17s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.42%)
# (_dystack pid=29375) 	0.887	 = Validation score   (accuracy)
# (_dystack pid=29375) 	4.47s	 = Training   runtime
# (_dystack pid=29375) 	0.15s	 = Validation runtime
# (_dystack pid=29375) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 260.76s of remaining time.
# (_dystack pid=29375) 	Ensemble Weights: {'NeuralNetTorch_BAG_L1': 1.0}
# (_dystack pid=29375) 	0.9057	 = Validation score   (accuracy)
# (_dystack pid=29375) 	0.26s	 = Training   runtime
# (_dystack pid=29375) 	0.0s	 = Validation runtime
# (_dystack pid=29375) Fitting 108 L2 models ...
# (_dystack pid=29375) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 260.49s of the 259.99s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.05%)
# (_dystack pid=29375) 	0.8995	 = Validation score   (accuracy)
# (_dystack pid=29375) 	11.81s	 = Training   runtime
# (_dystack pid=29375) 	0.34s	 = Validation runtime
# (_dystack pid=29375) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 243.67s of the 243.15s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.81%)
# (_dystack pid=29375) 	0.9057	 = Validation score   (accuracy)
# (_dystack pid=29375) 	10.07s	 = Training   runtime
# (_dystack pid=29375) 	0.16s	 = Validation runtime
# (_dystack pid=29375) Fitting model: LightGBM_BAG_L2 ... Training model for up to 229.04s of the 228.5s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.81%)
# (_dystack pid=29375) 	0.9057	 = Validation score   (accuracy)
# (_dystack pid=29375) 	12.96s	 = Training   runtime
# (_dystack pid=29375) 	0.14s	 = Validation runtime
# (_dystack pid=29375) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 211.55s of the 211.06s of remaining time.
# (_dystack pid=29375) 	0.8995	 = Validation score   (accuracy)
# (_dystack pid=29375) 	2.94s	 = Training   runtime
# (_dystack pid=29375) 	1.44s	 = Validation runtime
# (_dystack pid=29375) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 205.38s of the 204.89s of remaining time.
# (_dystack pid=29375) 	0.8977	 = Validation score   (accuracy)
# (_dystack pid=29375) 	2.87s	 = Training   runtime
# (_dystack pid=29375) 	1.52s	 = Validation runtime
# (_dystack pid=29375) Fitting model: CatBoost_BAG_L2 ... Training model for up to 199.2s of the 198.7s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.63%)
# (_ray_fit pid=12292) 	Many features detected (3590), dynamically setting 'colsample_bylevel' to 0.2785515320334262 to speed up training (Default = 1).
# (_ray_fit pid=12292) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters.
# (_dystack pid=29375) 	0.903	 = Validation score   (accuracy)
# (_dystack pid=29375) 	91.59s	 = Training   runtime
# (_dystack pid=29375) 	2.94s	 = Validation runtime
# (_ray_fit pid=12286) 	Many features detected (3591), dynamically setting 'colsample_bylevel' to 0.278473962684489 to speed up training (Default = 1). [repeated 7x across cluster]
# (_ray_fit pid=12286) 	To disable this functionality, explicitly specify 'colsample_bylevel' in the model hyperparameters. [repeated 7x across cluster]
# (_dystack pid=29375) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 102.72s of the 102.2s of remaining time.
# (_dystack pid=29375) 	0.8986	 = Validation score   (accuracy)
# (_dystack pid=29375) 	3.14s	 = Training   runtime
# (_dystack pid=29375) 	1.48s	 = Validation runtime
# (_dystack pid=29375) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 96.31s of the 95.79s of remaining time.
# (_dystack pid=29375) 	0.8968	 = Validation score   (accuracy)
# (_dystack pid=29375) 	2.46s	 = Training   runtime
# (_dystack pid=29375) 	1.4s	 = Validation runtime
# (_dystack pid=29375) Fitting model: XGBoost_BAG_L2 ... Training model for up to 90.68s of the 90.19s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.65%)
# (_dystack pid=29375) 	0.9021	 = Validation score   (accuracy)
# (_dystack pid=29375) 	13.37s	 = Training   runtime
# (_dystack pid=29375) 	0.26s	 = Validation runtime
# (_dystack pid=29375) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 72.72s of the 72.18s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# (_dystack pid=29375) 	0.9084	 = Validation score   (accuracy)
# (_dystack pid=29375) 	17.61s	 = Training   runtime
# (_dystack pid=29375) 	0.51s	 = Validation runtime
# (_dystack pid=29375) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 50.28s of the 49.76s of remaining time.
# (_dystack pid=29375) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=3.23%)
# (_dystack pid=29375) 	0.9039	 = Validation score   (accuracy)
# (_dystack pid=29375) 	39.97s	 = Training   runtime
# (_dystack pid=29375) 	0.18s	 = Validation runtime
# (_dystack pid=29375) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -38.66s of remaining time.
# (_dystack pid=29375) 	Ensemble Weights: {'NeuralNetTorch_BAG_L2': 1.0}
# (_dystack pid=29375) 	0.9084	 = Validation score   (accuracy)
# (_dystack pid=29375) 	0.34s	 = Training   runtime
# (_dystack pid=29375) 	0.0s	 = Validation runtime
# (_dystack pid=29375) AutoGluon training complete, total runtime = 934.12s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 9.0 rows/s (141 batch size)
# (_dystack pid=29375) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./jiewan-suyuan/test1/ds_sub_fit/sub_fit_ho")
# (_dystack pid=29375) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                           model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0               LightGBM_BAG_L1       0.900709   0.904804    accuracy        0.150420       0.135556    9.103812                 0.150420                0.135556           9.103812            1       True          3
# 1             LightGBMXT_BAG_L1       0.900709   0.904804    accuracy        0.217553       0.152032    9.428324                 0.217553                0.152032           9.428324            1       True          2
# 2          LightGBMLarge_BAG_L1       0.900709   0.898577    accuracy        0.271493       0.172124   24.666913                 0.271493                0.172124          24.666913            1       True         11
# 3          LightGBM_r131_BAG_L1       0.893617   0.900356    accuracy        0.175307       0.157606   16.094855                 0.175307                0.157606          16.094855            1       True         14
# 4         ExtraTreesGini_BAG_L1       0.893617   0.897687    accuracy        0.192688       1.776845    3.051776                 0.192688                1.776845           3.051776            1       True          7
# 5                XGBoost_BAG_L1       0.893617   0.898577    accuracy        0.360667       0.163502   11.257099                 0.360667                0.163502          11.257099            1       True          9
# 6             LightGBMXT_BAG_L2       0.893617   0.905694    accuracy       12.715915      20.806900  490.178233                 0.144379                0.163453          10.071229            2       True         20
# 7         ExtraTreesEntr_BAG_L2       0.893617   0.896797    accuracy       12.722008      22.047443  482.564576                 0.150472                1.403997           2.457573            2       True         26
# 8           LightGBM_r96_BAG_L1       0.886525   0.887011    accuracy        0.146944       0.152840    4.474719                 0.146944                0.152840           4.474719            1       True         17
# 9       RandomForestGini_BAG_L1       0.886525   0.896797    accuracy        0.185615       1.445269    3.160048                 0.185615                1.445269           3.160048            1       True          4
# 10        ExtraTreesEntr_BAG_L1       0.886525   0.898577    accuracy        0.192904       1.537119    3.210956                 0.192904                1.537119           3.210956            1       True          8
# 11      RandomForestEntr_BAG_L1       0.886525   0.897687    accuracy        0.197631       1.494895    3.274394                 0.197631                1.494895           3.274394            1       True          5
# 12  NeuralNetFastAI_r191_BAG_L1       0.886525   0.901246    accuracy        0.384911       0.434156   17.743565                 0.384911                0.434156          17.743565            1       True         15
# 13         CatBoost_r177_BAG_L1       0.886525   0.903025    accuracy        2.604254       4.035994  173.146147                 2.604254                4.035994         173.146147            1       True         12
# 14           CatBoost_r9_BAG_L1       0.886525   0.894128    accuracy        3.022068       4.344232   39.414581                 3.022068                4.344232          39.414581            1       True         16
# 15              CatBoost_BAG_L1       0.886525   0.894128    accuracy        3.148288       3.798324  113.184131                 3.148288                3.798324         113.184131            1       True          6
# 16              LightGBM_BAG_L2       0.886525   0.905694    accuracy       12.712235      20.783251  493.069628                 0.140699                0.139805          12.962625            2       True         21
# 17        ExtraTreesGini_BAG_L2       0.886525   0.898577    accuracy       12.720420      22.120216  483.249670                 0.148885                1.476769           3.142666            2       True         25
# 18      RandomForestGini_BAG_L2       0.886525   0.899466    accuracy       12.752774      22.084041  483.046270                 0.181238                1.440594           2.939266            2       True         22
# 19      RandomForestEntr_BAG_L2       0.886525   0.897687    accuracy       12.766652      22.164462  482.972038                 0.195116                1.521016           2.865034            2       True         23
# 20         LightGBMLarge_BAG_L2       0.886525   0.903915    accuracy       12.797139      20.822571  520.075313                 0.225604                0.179125          39.968310            2       True         29
# 21               XGBoost_BAG_L2       0.886525   0.902135    accuracy       12.932826      20.900901  493.478810                 0.361290                0.257455          13.371807            2       True         27
# 22              CatBoost_BAG_L2       0.886525   0.903025    accuracy       14.686329      23.588377  571.694326                 2.114793                2.944930          91.587322            2       True         24
# 23        NeuralNetTorch_BAG_L1       0.879433   0.905694    accuracy        0.381945       0.251801   20.536816                 0.381945                0.251801          20.536816            1       True         10
# 24          WeightedEnsemble_L2       0.879433   0.905694    accuracy        0.383972       0.252990   20.795322                 0.002027                0.001189           0.258505            2       True         18
# 25       NeuralNetFastAI_BAG_L1       0.879433   0.902135    accuracy        0.688077       0.249026   10.646755                 0.688077                0.249026          10.646755            1       True          1
# 26        NeuralNetTorch_BAG_L2       0.879433   0.908363    accuracy       12.917770      21.151542  497.712542                 0.346234                0.508096          17.605538            2       True         28
# 27          WeightedEnsemble_L3       0.879433   0.908363    accuracy       12.919945      21.152494  498.048483                 0.002175                0.000952           0.335942            3       True         30
# 28    NeuralNetTorch_r79_BAG_L1       0.872340   0.897687    accuracy        0.250772       0.342124   17.712112                 0.250772                0.342124          17.712112            1       True         13
# 29       NeuralNetFastAI_BAG_L2       0.872340   0.899466    accuracy       12.866294      20.981537  491.920179                 0.294758                0.338090          11.813175            2       True         19
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	960s	 = DyStack   runtime |	2640s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 2640s
# AutoGluon will save models to "./jiewan-suyuan/test1/"
# Train Data Rows:    1265
# Train Data Columns: 5502
# Label Column:       origin
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    84817.47 MB
# 	Train Data (Original)  Memory Usage: 6.64 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 5053 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 449): ['group_2529', 'ackA', 'group_2448', 'tdcB', 'hom', 'rplB', 'group_2431', 'bamA', 'slt', 'actP', 'ilvD', 'guaA', 'group_2411', 'engB', 'fbp', 'ruvA', 'group_2406', 'group_2402', 'group_2399', 'rpiB', 'group_2395', 'bpt...bpt_1...bpt_2', 'group_2393', 'dnaE', 'slyD', 'group_2356', 'dusB', 'atpD', 'folP', 'group_2297', 'atoC...dctD', 'group_2283', 'group_2271', 'purD', 'group_2218', 'purH', 'ycaD', 'group_2152', 'rplN', 'msrAB...msrA', 'group_2128', 'lptB_2', 'rpsZ', 'group_2074', 'group_2071', 'pal', 'group_2065', 'peb1A', 'group_2040', 'rplE', 'rpsH', 'gltA', 'sucC', 'group_2018', 'fliP', 'soj', 'lepA', 'group_2005', 'hiuH', 'glnM', 'aroA', 'group_1995', 'group_1994', 'group_1990', 'rpsS', 'flgG_1', 'group_1976', 'group_1966', 'fapR', 'murB', 'ilvC', 'lutA_2', 'group_1929', 'group_1925', 'glnA', 'group_1918', 'group_1908', 'cfiB', 'group_1900', 'group_1898', 'proP_2...yhjE...proP_3...proP_1...ousA', 'mltD', 'group_1894', 'group_1890', 'clpY', 'group_1883', 'ispH', 'metG', 'aroH', 'ilvH', 'hslV', 'yocK', 'group_1854', 'group_1853', 'lepB', 'cbf2', 'group_1831', 'pepA', 'group_1821', 'group_1819', 'group_1818', 'argH', 'folD', 'group_1813', 'murG', 'glyQ', 'rppH', 'yccU', 'recN', 'ycfH', 'alaC', 'group_1797', 'purE', 'group_1789', 'pheT', 'group_1761', 'pckA', 'atpG_2...atpG_1...atpG', 'group_1756', 'group_1755', 'group_1751', 'group_1737', 'nadK', 'group_1731', 'atpE', 'group_1715', 'cysK', 'artQ', 'pdxA', 'atpA', 'hup', 'fmt', 'group_1670', 'lptD', 'prs', 'pheS', 'serA', 'group_1638', 'group_1630', 'group_1602', 'group_1596', 'rpsA', 'ccsA', 'rhaS...exsA', 'yycB...nimT', 'cmoA', 'group_1436', 'group_1435', 'group_1434', 'group_1433', 'miaA', 'queE', 'mntP', 'group_1423', 'sodB', 'group_1400', 'yicL...yicL_1', 'group_1381', 'group_1374', 'oadA', 'rsmI_1...rsmI_2...rsmI', 'group_1353', 'atpC', 'exbD_1', 'ribBA', 'group_1280', 'trpC_1...trpC_3...trpC_2', 'group_1262', 'ftsW', 'group_1237', 'ansZ', 'group_1211', 'trmL...trmL_1...trmL_2', 'pleD', 'group_1193', 'group_1183', 'group_1176', 'group_1168', 'ydfG', 'alr', 'queA', 'group_1159', 'oprF', 'group_1141', 'group_1137', 'uppS', 'recJ', 'group_1110', 'selU', 'apt...apt_1...apt_2', 'group_1104', 'group_1095', 'prpD', 'group_1076', 'group_1071', 'group_1065', 'mrdA', 'ypdF', 'rsmG', 'pfeA...cirA_2...fepA...cirA_1...cirA_3', 'group_1026', 'purN', 'alsT...alsT_2...alsT_1', 'comM', 'glnP_2', 'cstA', 'pnp', 'flhA_2...flhA_1...flhA', 'group_982', 'rpsO', 'pfs_1...pfs', 'group_922', 'argF', 'group_914', 'ybeY', 'group_907', 'rpoN...rpoN_1...rpoN_2', 'tsaE', 'group_894', 'group_886', 'tatC', 'group_876', 'group_875', 'group_870', 'truA', 'gyrA', 'group_864', 'group_855', 'rsmA', 'group_847', 'PROSC', 'dapB', 'group_821', 'fba', 'group_753', 'group_748', 'group_739', 'group_732', 'rplF', 'bioB', 'hemL...hemL1', 'group_718', 'glmU', 'accC', 'tig...tig_2', 'atpF', 'yisK', 'rbr1', 'rplP', 'fliQ', 'group_679', 'group_678', 'rnr', 'amt...nrgA...nrgA_2...nrgA_1', 'guaB', 'group_612', 'group_605', 'group_595', 'group_593', 'secY', 'rpsE', 'dsbI', 'ispG', 'rplR', 'group_545', 'gltB_2...gltB_1...gltB', 'rplI', 'livF', 'fhaB...fhaB_2...ibpA', 'fhaC...fhaC_2...fhaC_1', 'group_489', 'nnr...nnr_2...nnr_1', 'glnQ_2...glnQ_3', 'pdxJ', 'rplM', 'group_449', 'lolE', 'rpsP', 'purF...purF_1', 'group_372', 'group_368', 'group_360', 'yajL', 'rpsG', 'ribF', 'argG', 'rpmE', 'group_321', 'glnH', 'aas...lplT', 'group_296', 'futA1', 'group_295', 'group_292', 'cymR', 'fabD', 'ttcA', 'yajC', 'rpsI', 'pepD_1...pepD_2...pepD', 'rplW', 'rpsC', 'rimM', 'sbmA', 'nucH', 'group_111', 'hemB', 'ppa', 'adk', 'parB', 'uup_1...uup', 'lptB_2...lptB_1', 'hemN', 'group_48', 'flaC', 'livH', 'group_43', 'psd', 'ffh', 'group_40', 'flgG_1...flgG_2', 'rplD', 'rpsQ', 'acnB', 'group_25', 'lpxD', 'group_22', 'fusA', 'group_21', 'rlmH', 'group_11', 'mntB...znuB...mntC', 'rlmN', 'rnj', 'fokIM...fokIM_1', 'grpE', 'group_1914', 'rlmB', 'accD', 'trxB', 'group_1593', 'moaA', 'pctB...mcp4...mcpB', 'pgsA', ' ...
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 1431): ['thiG', 'nrdA...nrdE', 'nth', 'thyX', 'metY', 'group_1954', 'ogt', 'group_1717', 'acsA...acs_1', 'ilvB', 'group_1241', 'mdtC...mdtB...mdtC_2...mdtC_1', 'group_1150', 'macA...macA_2...macA_1', 'gltX', 'asd', 'hipO', 'thrB', 'cobB_1...cobB', 'meh', 'tcyP', 'pyrG', 'rnhB', 'macB...macB_2', 'thiH', 'ychF', 'tdeA', 'group_463', 'moeA_2', 'ppk2', 'yiiM', 'dcuB_1...dcuB_3...dcuB_2...dcuB', 'metAA1', 'rsmF', 'rsmE', 'group_78', 'tlyA', 'group_2360', 'group_2130', 'ispB', 'ruvC', 'group_1542', 'cheR', 'lpxC', 'dnaJ', 'uvrB...uvrB_1', 'ileS', 'group_859', 'nadD', 'group_726', 'algC', 'group_708', 'group_705', 'group_693', 'gyrB', 'dnaA', 'rsfS', 'secD', 'tenI', 'group_313', 'gltB_1...gltB_2...gltA_2', 'topA...topA_1', 'resE', 'leuS', 'bzaF', 'rpe', 'tpiA', 'hxuB...hxuB_1', 'group_2083', 'group_2001', 'group_1006', 'group_983', 'hemC', 'mepA', 'hldE...hldE_1', 'group_508', 'secF', 'acsA_2...acs...acs_1', 'proA', 'group_1615', 'lon_2...lon...lon_1', 'rpsR', 'group_10', 'mnmE', 'purL', 'rpsM', 'rpsD', 'group_1296', 'petB', 'petA', 'mnmG', 'group_635', 'group_603', 'group_396', 'infA', 'group_467', 'rnpA', 'group_344', 'rplQ', 'murD', 'gpmI', 'fabG_1...fabG', 'argS', 'pglB', 'group_949', 'pglI...pglI_2...pglI_1', 'group_647', 'mdtI', 'rpsB', 'group_328', 'mdtJ...nepB', 'group_1641', 'cheA_1...cheA...frzE_1', 'group_417', 'tsf', 'cyf', 'copA_2...ctpA_1...copA_1', 'rho', 'group_1134', 'pglC', 'pglA', 'lolD', 'copA_2', 'group_364', 'group_88', 'group_84', 'group_82', 'flgC', 'group_566', 'group_168', 'group_2077', 'argB', 'ypeA', 'group_1004', 'argC', 'ldh...ldh_2...ldh_1', 'fabF', 'purS', 'purQ', 'purC', 'group_2089', 'nuoL', 'nuoN', 'pcm', 'dcuD_1...dcuD_2...dcuD...dcuD_3', 'metC...metC_2...metC_1', 'group_891', 'group_773', 'group_198', 'clpB', 'nuoH', 'nuoK', 'nuoJ', 'group_624', 'group_1757', 'sstT...sstT_1...sstT_2', 'mcpQ...mcp4...mcp4_1', 'group_395', 'wbpE_2...desV...wbpE_1...wbpE', 'group_189', 'hxcR...epsE', 'group_188', 'yohD', 'group_2038', 'group_2037', 'frr', 'pyrE', 'group_834', 'group_731', 'pcrA', 'group_382', 'group_381', 'group_63', 'atpB', 'pyrH', 'group_2079', 'tyrS', 'group_2076', 'group_422', 'pyrC_1...pyrC_2...pyrC', 'metN_1...ftsE', 'group_158', 'spoT...relA', 'mnmC_2...mnmC_1...mnmC', 'tsaD', 'recR', 'czcS', 'hydB', 'group_156', 'group_414', 'group_162', 'rplJ', 'rplA', 'rplK', 'nusG', 'rpmG2', 'tufA', 'tpx', 'cysE', 'napA', 'napB', 'speA', 'yecS', 'ctb', 'group_547', 'group_320', 'metN', 'ispE', 'group_221', 'group_175', 'group_340', 'aat', 'group_1248', 'group_190', 'group_750', 'group_2032', 'sucD', 'korA', 'group_457', 'group_1079', 'group_462', 'group_458', 'group_421', 'group_177', 'prfA', 'dapD', 'group_734', 'hisG', 'hisF_1', 'pgpA', 'mqo', 'group_263', 'serS', 'group_1997', 'yedF', 'group_940', 'der', 'group_178', 'mlaA', 'mqnE', 'group_749', 'nadE', 'group_418', 'group_179', 'msbA', 'group_1044', 'group_893', 'group_889', 'potA...cysA...malK...phnT', 'dapA', 'group_49', 'thrC', 'ylxH', 'folK', 'group_823', 'group_783', 'group_782', 'group_568', 'fliM', 'fliA', 'hpr', 'rplT', 'trpF...trpC_2...trpC_1', 'trpA', 'group_2322', 'group_2086', 'fliN', 'gppA', 'tcrA...cusR', 'pabB...trpE', 'cbpA', 'group_2104', 'group_100', 'group_109', 'prmA', 'ftsH', 'group_55', 'moaC1...moaC', 'group_616', 'group_201', 'lpxA', 'mreB...mreB_1', 'group_304', 'clpX', 'dgkA', 'group_530', 'lutB', 'group_723', 'group_754', 'ttuB...rhmT...rhmT_1...rhmT_2', 'group_369', 'uxaA_2...uxaA_1', 'glmM', 'yclQ...yclQ_2...yclQ_1', 'rpoD', 'mtaB', 'group_2239', 'glyA', 'group_1594', 'group_1517', 'group_254', 'aroE', 'lgt', 'frdA', 'frdC', 'group_744', 'group_2015', 'group_721', 'group_719', 'motB', 'group_2205', 'group_2204', 'group_2048', 'macB_2', 'group_232', 'tpd', 'group_2137', 'group_775', 'murI', 'map', 'nhaA_1...nhaA_2', 'group_2066', 'plsX', 'group_745', 'group_341', 'ndk', 'group_930', 'mlaE', 'torC', 'group_682', 'group_1759', 'tktA...tkt', 'dcuA_1...dcuA...dcuA_2', 'group_649', 'group_486', ' ...
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# ...
# 	No valid features to train KNeighborsUnif_BAG_L1... Skipping this model.
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2566.5s of the 2566.39s of remaining time.
# 	No valid features to train KNeighborsDist_BAG_L1... Skipping this model.
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2565.89s of the 2565.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8964	 = Validation score   (accuracy)
# 	12.96s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2546.68s of the 2546.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.81%)
# 	0.9067	 = Validation score   (accuracy)
# 	9.65s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2532.51s of the 2532.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.81%)
# 	0.9067	 = Validation score   (accuracy)
# 	9.81s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2518.26s of the 2518.14s of remaining time.
# 	0.8972	 = Validation score   (accuracy)
# 	3.48s	 = Training   runtime
# 	2.2s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2511.06s of the 2510.94s of remaining time.
# 	0.8957	 = Validation score   (accuracy)
# 	3.23s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2504.56s of the 2504.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.63%)
# 	0.8972	 = Validation score   (accuracy)
# 	144.15s	 = Training   runtime
# 	4.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2355.58s of the 2355.47s of remaining time.
# 	0.898	 = Validation score   (accuracy)
# 	3.21s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2348.83s of the 2348.72s of remaining time.
# 	0.898	 = Validation score   (accuracy)
# 	3.36s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2342.12s of the 2342.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.65%)
# 	0.902	 = Validation score   (accuracy)
# 	12.7s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2324.96s of the 2324.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.9059	 = Validation score   (accuracy)
# 	14.94s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2305.33s of the 2305.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=3.24%)
# 	0.8964	 = Validation score   (accuracy)
# 	28.07s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2272.52s of the 2272.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.63%)
# 	0.9012	 = Validation score   (accuracy)
# 	175.0s	 = Training   runtime
# 	4.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2092.77s of the 2092.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.8996	 = Validation score   (accuracy)
# 	13.96s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 2074.1s of the 2073.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.36%)
# 	0.9043	 = Validation score   (accuracy)
# 	16.79s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2052.65s of the 2052.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8941	 = Validation score   (accuracy)
# 	21.0s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 2026.77s of the 2026.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=6.41%)
# 	0.9004	 = Validation score   (accuracy)
# 	225.25s	 = Training   runtime
# 	4.14s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 1796.75s of the 1796.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.43%)
# 	0.902	 = Validation score   (accuracy)
# 	12.07s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 1780.24s of the 1780.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.9004	 = Validation score   (accuracy)
# 	18.21s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 1757.41s of the 1757.3s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 12.90% memory usage per fold, 51.61%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=8, gpus=0, memory=12.90%)
# 	0.9012	 = Validation score   (accuracy)
# 	30.43s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 1722.64s of the 1722.53s of remaining time.
# 	0.8854	 = Validation score   (accuracy)
# 	5.92s	 = Training   runtime
# 	1.74s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 1713.44s of the 1713.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.43%)
# 	0.8957	 = Validation score   (accuracy)
# 	49.86s	 = Training   runtime
# 	3.9s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 1658.78s of the 1658.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8727	 = Validation score   (accuracy)
# 	29.05s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 1625.06s of the 1624.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=6.42%)
# 	0.8972	 = Validation score   (accuracy)
# 	547.4s	 = Training   runtime
# 	3.9s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 1072.81s of the 1072.68s of remaining time.
# 	0.8901	 = Validation score   (accuracy)
# 	6.07s	 = Training   runtime
# 	1.77s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 1063.43s of the 1063.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=3.22%)
# 	0.9036	 = Validation score   (accuracy)
# 	21.5s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 1037.38s of the 1037.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8964	 = Validation score   (accuracy)
# 	21.22s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 1011.37s of the 1011.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.66%)
# 	0.9051	 = Validation score   (accuracy)
# 	11.44s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 995.53s of the 995.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.8988	 = Validation score   (accuracy)
# 	17.23s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 973.58s of the 973.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=2.27%)
# 	0.902	 = Validation score   (accuracy)
# 	6.32s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 962.76s of the 962.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.9028	 = Validation score   (accuracy)
# 	15.41s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 942.71s of the 942.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.43%)
# 	0.898	 = Validation score   (accuracy)
# 	40.61s	 = Training   runtime
# 	3.98s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 897.36s of the 897.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8877	 = Validation score   (accuracy)
# 	25.47s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 867.16s of the 867.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=3.27%)
# 	0.9028	 = Validation score   (accuracy)
# 	31.43s	 = Training   runtime
# 	3.03s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 830.97s of the 830.86s of remaining time.
# 	0.8885	 = Validation score   (accuracy)
# 	5.4s	 = Training   runtime
# 	1.93s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 822.08s of the 821.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.83%)
# 	0.8996	 = Validation score   (accuracy)
# 	85.11s	 = Training   runtime
# 	4.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 732.31s of the 732.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8957	 = Validation score   (accuracy)
# 	16.58s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 710.86s of the 710.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.8925	 = Validation score   (accuracy)
# 	12.16s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 693.99s of the 693.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=6.35%)
# 	0.9036	 = Validation score   (accuracy)
# 	23.5s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 665.8s of the 665.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.898	 = Validation score   (accuracy)
# 	13.3s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 647.78s of the 647.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=1.63%)
# 	0.9004	 = Validation score   (accuracy)
# 	89.71s	 = Training   runtime
# 	3.84s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 553.13s of the 553.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8688	 = Validation score   (accuracy)
# 	39.93s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 508.46s of the 508.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=3.37%)
# 	0.898	 = Validation score   (accuracy)
# 	24.74s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 479.33s of the 479.21s of remaining time.
# 	0.8901	 = Validation score   (accuracy)
# 	5.43s	 = Training   runtime
# 	2.12s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 470.19s of the 470.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=3.23%)
# 	0.9004	 = Validation score   (accuracy)
# 	376.67s	 = Training   runtime
# 	4.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 88.66s of the 88.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.8957	 = Validation score   (accuracy)
# 	18.71s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 65.21s of the 65.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.902	 = Validation score   (accuracy)
# 	15.05s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 45.49s of the 45.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=6.49%)
# 	0.9004	 = Validation score   (accuracy)
# 	37.44s	 = Training   runtime
# 	3.25s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -3.18s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.5, 'NeuralNetTorch_r22_BAG_L1': 0.25, 'XGBoost_r194_BAG_L1': 0.25}
# 	0.9083	 = Validation score   (accuracy)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2643.29s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 45.9 rows/s (159 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./jiewan-suyuan/test1/")

# %%
lboard = predictor.leaderboard()
lboard.sort_values(by='score_val', ascending=False)
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0           WeightedEnsemble_L2   0.908300    accuracy       3.463612
# 1             LightGBMXT_BAG_L1   0.906719    accuracy       0.159071
# 2               LightGBM_BAG_L1   0.906719    accuracy       0.160684
# 3         NeuralNetTorch_BAG_L1   0.905929    accuracy       0.266680
# 4            XGBoost_r89_BAG_L1   0.905138    accuracy       0.188665
# 5          LightGBM_r131_BAG_L1   0.904348    accuracy       0.187130
# 6          LightGBM_r188_BAG_L1   0.903557    accuracy       0.175907
# 7          LightGBM_r161_BAG_L1   0.903557    accuracy       0.176036
# 8     NeuralNetTorch_r86_BAG_L1   0.902767    accuracy       0.265327
# 9           XGBoost_r194_BAG_L1   0.902767    accuracy       3.029819
# 10         LightGBM_r130_BAG_L1   0.901976    accuracy       0.161747
# 11          LightGBM_r96_BAG_L1   0.901976    accuracy       0.185768
# 12               XGBoost_BAG_L1   0.901976    accuracy       0.233865
# 13    NeuralNetTorch_r41_BAG_L1   0.901976    accuracy       0.244654
# 14           XGBoost_r33_BAG_L1   0.901186    accuracy       0.211016
# 15         CatBoost_r177_BAG_L1   0.901186    accuracy       4.246172
# 16    NeuralNetTorch_r22_BAG_L1   0.900395    accuracy       0.273717
# 17           XGBoost_r98_BAG_L1   0.900395    accuracy       3.249635
# 18          CatBoost_r70_BAG_L1   0.900395    accuracy       3.843520
# 19           CatBoost_r9_BAG_L1   0.900395    accuracy       4.143989
# 20         CatBoost_r167_BAG_L1   0.900395    accuracy       4.541650
# 21    NeuralNetTorch_r79_BAG_L1   0.899605    accuracy       0.364943
# 22          CatBoost_r69_BAG_L1   0.899605    accuracy       4.065459
# 23    NeuralNetTorch_r30_BAG_L1   0.898814    accuracy       0.339242
# 24         LightGBM_r196_BAG_L1   0.898024    accuracy       0.176719
# 25  NeuralNetFastAI_r143_BAG_L1   0.898024    accuracy       0.305805
# 26        ExtraTreesEntr_BAG_L1   0.898024    accuracy       1.830548
# 27        ExtraTreesGini_BAG_L1   0.898024    accuracy       1.918389
# 28          CatBoost_r50_BAG_L1   0.898024    accuracy       3.980811
# 29      RandomForestGini_BAG_L1   0.897233    accuracy       2.199357
# 30          CatBoost_r13_BAG_L1   0.897233    accuracy       3.900325
# 31              CatBoost_BAG_L1   0.897233    accuracy       4.029975
# 32         LightGBMLarge_BAG_L1   0.896443    accuracy       0.217163
# 33       NeuralNetFastAI_BAG_L1   0.896443    accuracy       0.310295
# 34  NeuralNetFastAI_r145_BAG_L1   0.896443    accuracy       0.397261
# 35  NeuralNetFastAI_r103_BAG_L1   0.895652    accuracy       0.407870
# 36   NeuralNetFastAI_r95_BAG_L1   0.895652    accuracy       0.463276
# 37      RandomForestEntr_BAG_L1   0.895652    accuracy       1.732005
# 38         CatBoost_r137_BAG_L1   0.895652    accuracy       3.897435
# 39  NeuralNetFastAI_r191_BAG_L1   0.894071    accuracy       0.433184
# 40    NeuralNetTorch_r14_BAG_L1   0.892490    accuracy       0.265352
# 41     RandomForest_r195_BAG_L1   0.890119    accuracy       1.772829
# 42      RandomForest_r39_BAG_L1   0.890119    accuracy       2.119435
# 43       ExtraTrees_r172_BAG_L1   0.888538    accuracy       1.928282
# 44   NeuralNetFastAI_r11_BAG_L1   0.887747    accuracy       0.541621
# 45        ExtraTrees_r42_BAG_L1   0.885375    accuracy       1.744183
# 46  NeuralNetFastAI_r102_BAG_L1   0.872727    accuracy       0.676558
# 47  NeuralNetFastAI_r156_BAG_L1   0.868775    accuracy       0.626185
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0    59.651656                0.001004           0.361101            2
# 1     9.651853                0.159071           9.651853            1
# 2     9.810684                0.160684           9.810684            1
# 3    14.943048                0.266680          14.943048            1
# 4    11.435965                0.188665          11.435965            1
# 5    16.788416                0.187130          16.788416            1
# 6    21.500309                0.175907          21.500309            1
# 7    23.504397                0.176036          23.504397            1
# 8    15.414239                0.265327          15.414239            1
# 9    31.427528                3.029819          31.427528            1
# 10    6.322776                0.161747           6.322776            1
# 11   12.071346                0.185768          12.071346            1
# 12   12.695007                0.233865          12.695007            1
# 13   15.049887                0.244654          15.049887            1
# 14   30.430233                0.211016          30.430233            1
# 15  174.997008                4.246172         174.997008            1
# 16   18.211173                0.273717          18.211173            1
# 17   37.436610                3.249635          37.436610            1
# 18   89.707030                3.843520          89.707030            1
# 19  225.250085                4.143989         225.250085            1
# 20  376.666195                4.541650         376.666195            1
# 21   13.956489                0.364943          13.956489            1
# 22   85.108296                4.065459          85.108296            1
# 23   17.234596                0.339242          17.234596            1
# 24   24.738492                0.176719          24.738492            1
# 25   13.296822                0.305805          13.296822            1
# 26    3.361266                1.830548           3.361266            1
# 27    3.206939                1.918389           3.206939            1
# 28   40.614102                3.980811          40.614102            1
# 29    3.481660                2.199357           3.481660            1
# 30  547.395030                3.900325         547.395030            1
# 31  144.147191                4.029975         144.147191            1
# 32   28.070563                0.217163          28.070563            1
# 33   12.962895                0.310295          12.962895            1
# 34   21.215177                0.397261          21.215177            1
# 35   16.581292                0.407870          16.581292            1
# 36   18.705190                0.463276          18.705190            1
# 37    3.225278                1.732005           3.225278            1
# 38   49.863952                3.897435          49.863952            1
# 39   21.003385                0.433184          21.003385            1
# 40   12.164566                0.265352          12.164566            1
# 41    6.071645                1.772829           6.071645            1
# 42    5.428480                2.119435           5.428480            1
# 43    5.398670                1.928282           5.398670            1
# 44   25.465639                0.541621          25.465639            1
# 45    5.923995                1.744183           5.923995            1
# 46   29.047374                0.676558          29.047374            1
# 47   39.930115                0.626185          39.930115            1
#
#     can_infer  fit_order
# 0        True         48
# 1        True          2
# 2        True          3
# 3        True         10
# 4        True         27
# 5        True         14
# 6        True         25
# 7        True         38
# 8        True         30
# 9        True         33
# 10       True         29
# 11       True         17
# 12       True          9
# 13       True         46
# 14       True         19
# 15       True         12
# 16       True         18
# 17       True         47
# 18       True         40
# 19       True         16
# 20       True         44
# 21       True         13
# 22       True         35
# 23       True         28
# 24       True         42
# 25       True         39
# 26       True          8
# 27       True          7
# 28       True         31
# 29       True          4
# 30       True         23
# 31       True          6
# 32       True         11
# 33       True          1
# 34       True         26
# 35       True         36
# 36       True         45
# 37       True          5
# 38       True         21
# 39       True         15
# 40       True         37
# 41       True         24
# 42       True         43
# 43       True         34
# 44       True         32
# 45       True         20
# 46       True         22
# 47       True         41

# %%
test_data = TabularDataset('./jiewan-suyuan/testing.csv')
perf = predictor.evaluate(test_data, auxiliary_metrics=False)
perf
# Out:
# Loaded data from: ./jiewan-suyuan/testing.csv | Columns = 5503 / 5503 | Rows = 250 -> 250
# {'accuracy': 0.892}

# %%
y_test = test_data[label_column]  # values to predict
test_data_nolab = test_data.drop(columns=[label_column])  # delete label column to prove we're not cheating
test_data_nolab.head()
 
#预测->结果简明
#predictor = TabularPredictor.load("/media/dell/cdcc2551-b430-4b85-a0f1-c628cb818672/zhenjun/shamen/ag/test3")  # unnecessary, just demonstrates how to load previously-trained predictor from file
y_pred = predictor.predict(test_data_nolab,as_pandas=True)
y_pred.to_csv("./jiewan-suyuan/jiewantest-result.csv")
#print("Predictions:  \n", y_pred)
#perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)

# %%
y_pred
# Out:
# 0       bovine
# 1        swine
# 2       bovine
# 3        swine
# 4      chicken
#         ...
# 245    chicken
# 246    chicken
# 247    chicken
# 248    chicken
# 249    chicken
# Name: origin, Length: 250, dtype: object

# %%
preict_data_full = TabularDataset('./jiewan-suyuan/prediction-data.csv')
preict_data_full
pred_probablities = predictor.predict(preict_data_full, as_pandas=True)
pred_probablities.to_csv('results_predict_50-jiewan.csv', index=False, encoding='utf-8')
pred_probablities
# Out:
# Loaded data from: ./jiewan-suyuan/prediction-data.csv | Columns = 5503 / 5503 | Rows = 20 -> 20
# 0     chicken
# 1     chicken
# 2     chicken
# 3     chicken
# 4     chicken
# 5     chicken
# 6     chicken
# 7     chicken
# 8     chicken
# 9     chicken
# 10    chicken
# 11      swine
# 12    chicken
# 13    chicken
# 14    chicken
# 15    chicken
# 16    chicken
# 17    chicken
# 18    chicken
# 19    chicken
# Name: origin, dtype: object
